# %%
# 2.1
import matplotlib.pyplot as plt
import numpy as np 
import math

fig, ax = plt.subplots()

f = 1.0
fs = 5.0
t = np.arange(-1,1+1/fs,1/fs)

x = np.sin(2*math.pi*f*t)
ax.plot (t,x,'o-')
ax.set_xlabel('Time',fontsize = 18)
ax.set_ylabel('Amplitude', fontsize = 18)
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
import matplotlib.pyplot as plt
import numpy as np 
import math

 fig, ax = plt.subplots()
ax.plot(t,x,'o-')
ax.axis(xmin = 1/(4*f)-1/fs*3,
xmax = 1/(4*f)+1/fs*3,
ymin = 0,
ymax = 1.1 )
ax.set_xlabel('Time',fontsize=18)
ax.set_ylabel('Amplitude',fontsize=18)
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
#2.3
import matplotlib.pyplot as plt
import numpy as np 
import math

interval=[] # miền
apprx = [] # dòng trên miền
 # build up points *evenly* inside of intervals
 #tạo ma trận từ các khối
tp = np.hstack([np.linspace(t[i],t[i+1],20,False) for i in range(len(t)-1)])
 # xây dựng đối số cho từng mảnh
for i in range(len(t)-1):
    interval.append(np.logical_and(t[i] <= tp,tp < t[i+1]))
    apprx.append((x[i+1]-x[i])/(t[i+1]-t[i])*(tp[interval[-1]]-t[i]) + x[i])
   
x_hat = np.piecewise(tp,interval,apprx) # xấp xỉ tuyển tính từng mảng

# %%
#2.4 
import matplotlib.pyplot as plt
import numpy as np 
import math

fig,ax1=plt.subplots()
# fill in the difference between the interpolant and the sine
ax1.fill_between(tp,x_hat,np.sin(2*math.pi*f*tp),facecolor='red')
ax1.set_xlabel('Time',fontsize=18)
ax1.set_ylabel('Amplitude',fontsize=18)
ax2 = ax1.twinx() # nhân đôi trục ax1
sqe = (x_hat-np.sin(2*math.pi*f*tp))**2 #compute squared-error
ax2.plot(tp, sqe,'r')
ax2.axis(xmin=-1,ymax= sqe.max() )
ax2.set_ylabel('Squared error', color='r',fontsize=18)
ax1.set_title('Errors with Piecewise Linear Interpolant',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Errors with Piecewise Linear Interpolant')

# %%
#2.5 vẽ nhiều đường với chức năng riêng lẻ

import matplotlib.pyplot as plt
import numpy as np 
import math
fig,ax = plt.subplots()
t = np.linspace(-1,1,100) # redefine this here for convenience
ts = np.arange(-1,1+1/fs,1/fs) # sample points
num_coeffs=len(ts)
sm=0
for k in range(-num_coeffs,num_coeffs): # since function is real, need both
    sm+=np.sin(2*math.pi*(k/fs))*np.sinc(k - fs*t)
ax.plot(t,sm,'--',t,np.sin(2*math.pi*t),ts, np.sin(2*math.pi*ts),'o')
ax.set_title('Sampling Rate=%3.2f Hz' % fs, fontsize=18 )
# Out:
# Text(0.5, 1.0, 'Sampling Rate=5.00 Hz')

# %%
#2.6
import matplotlib.pyplot as plt
import numpy as np 
import math

fig,ax1= plt.subplots()
ax1.fill_between(t,sm,np.sin(2*math.pi*f*t),facecolor='blue')
ax1.set_ylabel('Amplitude',fontsize=18)
ax1.set_xlabel('Time',fontsize=18)
ax2 = ax1.twinx()
sqe = (sm - np.sin(2*math.pi*f*t))**2
ax2.plot(t, sqe,'b')
ax2.axis(xmin=0,ymax = sqe.max())
ax2.set_ylabel('Squared Error', color='b',fontsize=18)
ax1.set_title('Errors with Whittaker Interpolant',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Errors with Whittaker Interpolant')

# %%
#2.7
import matplotlib.pyplot as plt
import numpy as np 
import math


fig,ax=plt.subplots()
k=0
fs=2 # makes this plot easier to read
ax.plot(t,np.sinc(k - fs * t),
t,np.sinc(k+1 - fs * t),'--',k/fs,1,'o',(k)/fs,0,'o',
t,np.sinc(k-1 - fs * t),'--',k/fs,1,'o',(-k)/fs,0,'o'
)
ax.hlines(0,-1,1) # horizontal lines
ax.vlines(0,-.2,1) # vertical lines
ax.annotate('sample value goes here',
xy=(0,1), # arrowhead position
xytext=(-1+.1,1.1),# text position
arrowprops={'facecolor':'red',
'shrink':0.05},
)
ax.annotate('no interference here',
xy=(0,0),
xytext=(-1+.1,0.5),
arrowprops={'facecolor':'green','shrink':0.05},
)
# Out:
# Text(-0.9, 0.5, 'no interference here')

# %%
#2.8
import matplotlib.pyplot as plt
import numpy as np 
import math

fs=5.0 # sampling rate
k=np.array(sorted(set((t*fs).astype(int)))) # sorted coefficient list
fig,ax = plt.subplots()
ax.plot(t,(np.sin(2*math.pi*(k[:,None]/fs))*np.sinc(k[:,None]-fs*t)).T,'--', # individual
 t,(np.sin(2*math.pi*(k[:,None]/fs))*np.sinc(k[:,None]-fs*t)).
sum(axis=0),'k-', # whittaker interpolant k/fs,
np.sin(2*math.pi*k/fs),'ob')# samples
ax.set_xlabel('Time',fontsize=18)
ax.set_ylabel('Amplitude',fontsize=18)
ax.set_title('Sine Reconstructed with Whittaker Interpolator')
ax.axis((-1.1,1.1,-1.1,1.1));

# %%
#2.9
import matplotlib.pyplot as plt
import numpy as np 
import math

t = np.linspace(-5,5,300) # redefine this here for convenience
fig,ax = plt.subplots()
fs=5.0 # sampling rate
ax.plot(t,np.sinc(fs * t))
ax.grid() # put grid on axes
ax.annotate('This keeps going...',xy=(-4,0),xytext=(-5+.1,0.5),arrowprops={'facecolor':'green','shrink':0.05},fontsize=14)

ax.annotate('... and going...',xy=(4,0),xytext=(3+.1,0.5),
arrowprops={'facecolor':'green','shrink':0.05},fontsize=14)
# Out:
# Text(3.1, 0.5, '... and going...')

# %%
#2.10
import matplotlib.pyplot as plt
import numpy as np 
import math

def kernel(x,sigma=1):
    'convenient function to compute kernel of eigenvalue problem'
    x = np.asanyarray(x) # ensure x is array
    y = math.pi*np.where(x == 0,1.0e-20, x)# avoid divide by zero
    return np.sin(sigma/2*y)/y

nstep=100 # quick and dirty integral quantization
t = np.linspace(-1,1,nstep) # quantization of time
dt = np.diff(t)[0] # differential step size

def eigv(sigma):
    return np.linalg.eigvalsh(kernel(t-t[:,None],sigma)).max() # compute max eigenvalue

sigma = np.linspace(0.01,4,15) # range of time-bandwidth products to consider
fig,ax = plt.subplots()
arr= np.array([eigv(i) for i in sigma])
ax.plot(sigma,dt*arr,'-o')
ax.set_xlabel('Time-bandwidth product $\sigma$',fontsize=18)
ax.set_ylabel('Maximum Eigenvalue',fontsize=18)
ax.axis(ymax=1.01)
ax.grid()

# %%
#2.11
import matplotlib.pyplot as plt
import numpy as np 
import math

sigma=3 # time-bandwidth product
w,v = np.linalg.eigh(kernel(t-t[:,None],sigma)) # eigen-system
maxv=v[:, w.argmax()] # eigenfunction for max eigenval
fig,ax=plt.subplots()
ax.plot(t,maxv)
ax.set_xlabel('$t$',fontsize=22)
ax.set_ylabel('$\psi_0(t)$',fontsize=22)
ax.set_title('Eigenvalue=%3.4f;$\sigma$=%3.2f'%(w.max()*dt,sigma))
# Out:
# Text(0.5, 1.0, 'Eigenvalue=0.9990;$\\sigma$=3.00')

# %%
#2.12
import matplotlib.pyplot as plt
import numpy as np 
import math

def kernel_tau(x,W=1):
    'convenient function to compute kernel of eigenvalue problem'
    x = np.asanyarray(x)
    y = math.pi*np.where(x == 0,1.0e-20, x) # avoid divide by zero
    return np.sin(2*W*y)/y
nstep=300 # quick and dirty integral quantization
t = np.linspace(-1,1,nstep) # quantization of time
tt = np.linspace(-2,2,nstep)# extend interval
sigma = 5
W = sigma/2./2./t.max()
w,v=np.linalg.eig(kernel_tau(t-tt[:,None],W)) # compute e-vectors/e-values
maxv=v[:,w.real.argmax()].real # take real part
fig,ax = plt.subplots()

ax.plot(tt , maxv/np.sign(maxv/[nstep/2]) ) 
ax.set_xlabel('$t$',fontsize=24)
ax.set_ylabel('$\phi_{max}(t)$',fontsize=24)
ax.set_title('$\sigma=%d$'%(2*W*2*t.max()),fontsize=26)
# Out:
# Text(0.5, 1.0, '$\\sigma=5$')

# %%
2.13
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d as a3
import matplotlib.colors as colors
import numpy as np 
import math

def facet_filled(x,alpha=0.5,color='b'):
    'construct 3D facet from adjacent points filled to zero'
    a,b=x
    a0= a*array([1,1,0])
    b0= b*array([1,1,0])
    ve = np.vstack([a,a0,b0,b]) # create closed polygon facet
    poly = a3.art3d.Poly3DCollection([ve]) # create facet
    poly.set_alpha(alpha) # set transparency
    poly.set_color(color)
    return poly
def drawDFTView(X,ax=None,fig=None):
    'Draws 3D diagram given DFT matrix'
    a=2*pi/len(X)*np.arange(len(X))
    d=np.vstack([np.cos(a),np.sin(a),array(abs(X)).flatten()]).T
    if ax is None and fig is None:
        fig = plt.figure()
        fig.set_size_inches(6,6)
    if ax is None: # add ax to existing figure
        ax = fig.add_subplot(1, 1, 1, projection='3d')
        ax.axis([-1,1,-1,1]) # x-y limits
        ax.set_zlim([0,d[:,2].max()]) # z-limit
        ax.set_aspect(1) # aspect ratio
        ax.view_init(azim=-30) # camera view position

a=a3.art3d.FancyArrow(0,0,1,0,width=0.02,length_includes_head=True)
ax.add_patch(a)
b=a3.art3d.FancyArrow(0,0,0,1,width=0.02,length_includes_head=True)
ax.add_patch(b)
a3.art3d.patch_2d_to_3d(a) # format 2D patch for 3D plot
a3.art3d.patch_2d_to_3d(b)
ax.axis('off')
sl=[slice(i,i+2) for i in range(d.shape[0]-2)] # collect neighboring points
for s in sl:
    poly=facet_filled(d[s,:])
ax.add_collection3d(poly)
# edge polygons
ax.add_collection3d(facet_filled(d[[-1,0],:]))
ax.add_collection3d(facet_filled(d[[-2,-1],:]))
def drawInOut(X,v,return_axes=False):
    fig = plt.figure()
fig.set_size_inches(8,8)
gs = gridspec.GridSpec(8,6)
ax1 = plt.subplot(gs[3:5,:2])
ax2 = plt.subplot(gs[:,2:],projection = '3d')
ax1.stem(arange(len(v)),v)
ymin,ymax= ax1.get_ylim()
ax1.set_ylim(ymax = ymax*1.2, ymin = ymin*1.2)
ax1.set_title('Signal')
ax1.set_xlabel('n')
ax1.tick_params(labelsize=8)
drawDFTView(X,ax2)
if return_axes:
    return ax1,ax2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-153-e1b201da86f1> in <module>
#      30         ax.view_init(azim=-30) # camera view position
#      31
# ---> 32 a=a3.art3d.FancyArrow(0,0,1,0,width=0.02,length_includes_head=True)
#      33 ax.add_patch(a)
#      34 b=a3.art3d.FancyArrow(0,0,0,1,width=0.02,length_includes_head=True)
#
# AttributeError: module 'mpl_toolkits.mplot3d.art3d' has no attribute 'FancyArrow'
